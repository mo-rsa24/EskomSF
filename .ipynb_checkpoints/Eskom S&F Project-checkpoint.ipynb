# %%
import warnings
warnings.filterwarnings('ignore')
import re
from db.queries import get_sample_rows, get_user_forecast_data, row_to_config
import os

# %%
os.environ["ENV"] = "DEV"

# %%
ufm_df = get_user_forecast_data()
ufm_df.head()
# Out:
#     StartDate     EndDate Parameters Region     Status  ForecastMethodID  \
# 0  2025-02-01  2028-01-31    (3,3,3)     EC  Completed                 1
#
#    UserForecastMethodID                                       CustomerJSON  \
# 0                   171  {"CSA": ["KSACS - Empangeni","KSACS - George",...
#
#                                              varJSON Method  DatabrickID
# 0  {"VariableID": ["OffPeakConsumption","PeakCons...  ARIMA           39

# %%
from etl.etl import *

# %%
all_prediction_columns = ["PeakConsumption", "StandardConsumption", "OffPeakConsumption","Block1Consumption", "Block2Consumption","Block3Consumption", "Block4Consumption",     "NonTOUConsumption"]

metadata = extract_metadata(ufm_df)
customer_ids = parse_json_column(ufm_df, "CustomerJSON")
variable_ids = parse_json_column(ufm_df, "varJSON", key="VariableID")
columns_mapping = generate_combinations(all_prediction_columns)

logging.info(f"Customer IDs: {customer_ids}")
logging.info(f"Variable IDs: {variable_ids}")
logging.info(f"✅ Total column combinations: {len(columns_mapping)}")
# Out:
# INFO:root:Generated 255 column combinations.
# INFO:root:Customer IDs: ['KSACS - Empangeni', 'KSACS - Bellville', 'KSACS - George']
# INFO:root:Variable IDs: ['NonTOUConsumption', 'StandardConsumption', 'Block1Consumption', 'PeakConsumption', 'Block4Consumption', 'Block3Consumption', 'Block2Consumption', 'OffPeakConsumption']
# INFO:root:✅ Total column combinations: 255

# %%
print(f"✅ Total combinations: {len(generate_combinations(all_prediction_columns))}\n")
# Out:
# INFO:root:Generated 255 column combinations.
# ✅ Total combinations: 255

# %%
selected_columns = find_matching_combination(columns_mapping, all_prediction_columns)
# Out:
# INFO:root:Exact match found for: frozenset({'NonTOUConsumption', 'StandardConsumption', 'Block1Consumption', 'PeakConsumption', 'Block4Consumption', 'Block3Consumption', 'Block2Consumption', 'OffPeakConsumption'})

# %%
if selected_columns:
    logging.info(f"Selected Columns: {selected_columns}")
else:
    logging.error("No matching columns found in AllVariables")
# Out:
# INFO:root:Selected Columns: ['ReportingMonth', 'CustomerID', 'PeakConsumption', 'StandardConsumption', 'OffPeakConsumption', 'Block1Consumption', 'Block2Consumption', 'Block3Consumption', 'Block4Consumption', 'NonTOUConsumption']

# %%
from dml.dml import *

# %%
df = load_and_prepare_data("PredictiveInputData.csv")
df.head()
# Out:
# INFO:root:✅ Raw dataset loaded.
# INFO:root:✅ Raw dataset cleaned.
#                     PodID  CustomerID  TariffID  PeakConsumption  \
# ReportingMonth
# 2021-04-01      736171562  7397925811  MEGAFLEX         141734.0
# 2021-05-01      736171562  7397925811  MEGAFLEX         148250.0
# 2021-06-01      736171562  7397925811  MEGAFLEX         153818.0
# 2021-07-01      736171562  7397925811  MEGAFLEX         182204.0
# 2021-08-01      736171562  7397925811  MEGAFLEX         144534.0
#
#                 StandardConsumption  OffPeakConsumption  Block1Consumption  \
# ReportingMonth
# 2021-04-01                 409040.0            647244.0                0.0
# 2021-05-01                 382914.0            561082.0                0.0
# 2021-06-01                 394294.0            552320.0                0.0
# 2021-07-01                 455822.0            659894.0                0.0
# 2021-08-01                 388444.0            621796.0                0.0
#
#                 Block2Consumption  Block3Consumption  Block4Consumption  \
# ReportingMonth
# 2021-04-01                    0.0                0.0                0.0
# 2021-05-01                    0.0                0.0                0.0
# 2021-06-01                    0.0                0.0                0.0
# 2021-07-01                    0.0                0.0                0.0
# 2021-08-01                    0.0                0.0                0.0
#
#                 NonTOUConsumption
# ReportingMonth
# 2021-04-01                    0.0
# 2021-05-01                    0.0
# 2021-06-01                    0.0
# 2021-07-01                    0.0
# 2021-08-01                    0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 175 entries, 2021-04-01 to 2024-02-01
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   PodID                175 non-null    int64
#  1   CustomerID           175 non-null    object
#  2   TariffID             175 non-null    object
#  3   PeakConsumption      175 non-null    float64
#  4   StandardConsumption  175 non-null    float64
#  5   OffPeakConsumption   175 non-null    float64
#  6   Block1Consumption    175 non-null    float64
#  7   Block2Consumption    175 non-null    float64
#  8   Block3Consumption    175 non-null    float64
#  9   Block4Consumption    175 non-null    float64
#  10  NonTOUConsumption    175 non-null    float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 16.4+ KB

# %%
row = ufm_df.iloc[0]
config = row_to_config(row)

# %%
config
# Out:
# ForecastConfig(forecast_method_id=1, forecast_method_name='ARIMA', model_parameters='(3,3,3)', region='EC', status='Completed', user_forecast_method_id=171, start_date=datetime.date(2025, 2, 1), end_date=datetime.date(2028, 1, 31), databrick_id=39)

# %%
if df.empty:
    logging.error("🚫 DataFrame is empty. Check input filters or data source.")
else:
    customer_ids, pod_ids = get_unique_list_of_customer_and_pod(df)

    # These variables should come from user input / config
    StartDate = config.start_date
    EndDate = config.end_date
    Hyper_Parameters = config.model_parameters

    forecast_dates = get_forecast_range(StartDate, EndDate)
    arima_order, seasonal_order = extract_sarimax_params(Hyper_Parameters)

    # Extract actuals range
    latest_actual_date = df.index.max()
    logging.info(f"📍 Last actuals month in data: {latest_actual_date.strftime('%Y-%m')}")
# Out:
# INFO:root:🧮 Forecasting for 2 customers: ['7397925811', '7999245034']
# INFO:root:📅 Forecast period: 2025-02-01 00:00:00 to 2028-01-01 00:00:00
# INFO:root:📌 Parsed ARIMA Order: (3, 3, 3), Seasonal Order: (0, 0, 0)
# INFO:root:📍 Last actuals month in data: 2024-02

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Select a small sample of customers for clearer plots
top_customers = df['CustomerID'].value_counts().head(4).index.tolist()
sample_df = df[df['CustomerID'].isin(top_customers)]
sample_df = df.reset_index()
# Melt the dataframe for easier time series plotting
melted_df = pd.melt(
   sample_df,
    id_vars=['CustomerID', 'ReportingMonth'],
    value_vars=[
        'PeakConsumption', 'StandardConsumption', 'OffPeakConsumption',
        'Block1Consumption', 'Block2Consumption', 'Block3Consumption',
        'Block4Consumption', 'NonTOUConsumption'
    ],
    var_name='ConsumptionType',
    value_name='kWh'
)
melted_df
# Out:
#       CustomerID ReportingMonth    ConsumptionType       kWh
# 0     7397925811     2021-04-01    PeakConsumption  141734.0
# 1     7397925811     2021-05-01    PeakConsumption  148250.0
# 2     7397925811     2021-06-01    PeakConsumption  153818.0
# 3     7397925811     2021-07-01    PeakConsumption  182204.0
# 4     7397925811     2021-08-01    PeakConsumption  144534.0
# ...          ...            ...                ...       ...
# 1395  7397925811     2023-10-01  NonTOUConsumption       0.0
# 1396  7397925811     2023-11-01  NonTOUConsumption       0.0
# 1397  7397925811     2023-12-01  NonTOUConsumption       0.0
# 1398  7397925811     2024-01-01  NonTOUConsumption       0.0
# 1399  7397925811     2024-02-01  NonTOUConsumption       0.0
#
# [1400 rows x 4 columns]

# %%
# Plot
plt.figure(figsize=(16, 10))
sns.lineplot(data=melted_df, x='ReportingMonth', y='kWh', hue='ConsumptionType', style='CustomerID')
plt.title("Customer-Level Electricity Consumption Trends")
plt.xlabel("Reporting Month")
plt.ylabel("Consumption (kWh)")
plt.xticks(rotation=45)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# 📊 Visualization: Customer-Level Electricity Consumption Trends
# This chart shows how different types of electricity consumption evolve over time for a sample of top customers:
#
# 🧩 Insights:
# Seasonal patterns are visible — especially in PeakConsumption and Block1Consumption.
#
# Customer behavior varies — some use more off-peak or flat-rate (NonTOU) power.
#
# Trends help you:
#
# Choose which features to forecast.
#
# Spot outliers or data quality issues.
#
# Guide model segmentation (e.g., cluster by consumption type).

# %%
# Define consumption columns
consumption_cols = [
    'PeakConsumption', 'StandardConsumption', 'OffPeakConsumption',
    'Block1Consumption', 'Block2Consumption', 'Block3Consumption',
    'Block4Consumption', 'NonTOUConsumption'
]

# Get top customers for plotting
top_customers = df['CustomerID'].value_counts().head(4).index.tolist()
sample_df = df[df['CustomerID'].isin(top_customers)]
sample_df = df.reset_index()
# Create subplots for each consumption type
fig, axes = plt.subplots(len(consumption_cols), 1, figsize=(16, 28), sharex=True)

for i, col in enumerate(consumption_cols):
    ax = axes[i]
    for cust_id in top_customers:
        cust_df = sample_df[sample_df['CustomerID'] == cust_id]
        ax.plot(cust_df['ReportingMonth'], cust_df[col], marker='o', label=f'Customer {cust_id}')
    ax.set_title(f"{col} Over Time")
    ax.set_ylabel("kWh")
    ax.grid(True)
    ax.legend(loc="upper right")
    # ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

plt.xlabel("Reporting Month")
plt.tight_layout()
plt.show()

# %% [markdown]
# 📈 Individual Consumption Trends per Type (Top Customers)
# Each plot above shows how a specific consumption type evolves monthly for the top 4 customers. Here's what we can observe:
#
# 🧠 Key Observations:
# PeakConsumption & Block1Consumption show clear periodic trends for some customers.
#
# Block2–Block4Consumption is flat or zero in many cases, indicating:
#
# Low usage customers not reaching higher billing tiers.
#
# Good candidates to drop or impute if doing dimensionality reduction.
#
# NonTOUConsumption is high and consistent for some — suggesting they are on flat-rate tariffs.
#
# 🔍 Suggested Next Steps for EDA (Exploratory Data Analysis)
# Here’s a breakdown of what we should do to deepen understanding before modeling:
#
# ✅ 1. Seasonality & Stationarity Checks
# Autocorrelation Plots (ACF, PACF) to detect periodicity.
#
# Augmented Dickey-Fuller Test for stationarity (needed for ARIMA/SARIMA).
#
# ✅ 2. Missing Data / Anomaly Detection
# Check for missing months or sudden spikes.
#
# Plot z-scores or IQRs for each column to detect anomalies.
#
# ✅ 3. Customer Segmentation
# Cluster customers based on consumption profiles (e.g., KMeans, t-SNE).
#
# Helps in building segmented models for better accuracy.
#
# ✅ 4. Correlation Heatmap
# Explore correlation between consumption types.
#
# Can inform dimensionality reduction (e.g., PCA).
#
# ✅ 5. Rolling Mean & Variance Plots
# Visualize changes in trend or volatility over time.
#
# Essential for model diagnostics.

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller

# %%
# Prepare data for a single customer to perform time series diagnostics
df = df.reset_index()
single_customer = df['CustomerID'].value_counts().idxmax()
cust_df = df[df['CustomerID'] == single_customer].sort_values('ReportingMonth')
# Select a single time series (e.g., PeakConsumption)
ts = cust_df.set_index('ReportingMonth')['PeakConsumption']

# %%
# 1. ACF and PACF Plots
fig, axes = plt.subplots(2, 1, figsize=(12, 8))
plot_acf(ts, ax=axes[0], lags=24)
plot_pacf(ts, ax=axes[1], lags=24)
axes[0].set_title(f"ACF - PeakConsumption ({single_customer})")
axes[1].set_title(f"PACF - PeakConsumption ({single_customer})")
plt.tight_layout()
plt.show()

# %%
# 2. Augmented Dickey-Fuller Test for Stationarity
adf_result = adfuller(ts.dropna())
adf_output = {
    'Test Statistic': adf_result[0],
    'p-value': adf_result[1],
    'Lags Used': adf_result[2],
    'Number of Observations': adf_result[3],
    'Critical Values': adf_result[4]
}
adf_output
# Out:
# {'Test Statistic': -12.052309511410055,
#  'p-value': 2.5804649616256194e-22,
#  'Lags Used': 1,
#  'Number of Observations': 138,
#  'Critical Values': {'1%': -3.47864788917503,
#   '5%': -2.882721765644168,
#   '10%': -2.578065326612056}}

# %% [markdown]
# ✅ 1. ACF & PACF Results – PeakConsumption for Most Active Customer
# ACF (Autocorrelation Function) shows clear periodicity and gradual decay — a sign of seasonality.
#
# PACF (Partial Autocorrelation Function) shows a few significant lags, suggesting possible AR components.

# %% [markdown]
# ✅ 2. Augmented Dickey-Fuller (ADF) Test for Stationarity
# 📌 Interpretation:
# The ADF test statistic is much lower than the 1% threshold.
#
# The p-value is far below 0.05, which means:
#
# ✅ The time series is stationary, and differencing is likely not needed.

# %%
consumption_cols = [
    'PeakConsumption', 'StandardConsumption', 'OffPeakConsumption',
    'Block1Consumption', 'Block2Consumption', 'Block3Consumption',
    'Block4Consumption', 'NonTOUConsumption'
]

correlation_matrix = df[consumption_cols].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", square=True)
plt.title("Correlation Matrix of Consumption Types")
plt.tight_layout()
plt.show()

# %% [markdown]
# 🔗 Correlation Matrix: Consumption Types
# 📊 Insights:
# High correlation between:
#
# PeakConsumption and StandardConsumption → Similar temporal behavior.
#
# Block1 and StandardConsumption → Users often stay within the first tier during standard hours.
#
# Low or no correlation:
#
# Block3, Block4 show weaker correlations — these may be sparsely used or rare.
#
# NonTOUConsumption has moderate correlation with StandardConsumption, which is expected as both relate to consistent usage patterns.
#
# 💡 Implications:
# Highly correlated features may be redundant in a predictive model.
#
# Dimensionality reduction (e.g., PCA) could be applied.
#
# You could choose a subset of these features to avoid multicollinearity.

# %%
# 4. Rolling Mean & Variance for PeakConsumption of selected customer
window_size = 6  # 6-month rolling window

ts = cust_df.set_index('ReportingMonth')['PeakConsumption']
rolling_mean = ts.rolling(window=window_size).mean()
rolling_std = ts.rolling(window=window_size).std()

plt.figure(figsize=(12, 6))
plt.plot(ts, label='Original', color='blue')
plt.plot(rolling_mean, label=f'{window_size}-Month Rolling Mean', color='orange')
plt.plot(rolling_std, label=f'{window_size}-Month Rolling Std Dev', color='green')
plt.title(f"Rolling Statistics - PeakConsumption (Customer {single_customer})")
plt.xlabel("Reporting Month")
plt.ylabel("kWh")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# 📉 Rolling Statistics: PeakConsumption for Selected Customer
# 📌 Interpretation:
# Rolling Mean shows smooth seasonality with some upward and downward trends, indicating non-constant behavior over time.
#
# Rolling Std Dev (volatility) varies, with peaks suggesting unusual or variable months.
#
# 🧠 Why This Matters:
# Helps diagnose trend and heteroskedasticity (changing variance).
#
# If using models like ARIMA or LSTM, rolling stats inform:
#
# Whether differencing or transformations are needed.
#
# Where to apply smoothing or anomaly detection.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# 5. Customer Segmentation Based on Consumption Profiles

# Aggregate average consumption per customer
customer_profiles = df.groupby('CustomerID')[consumption_cols].mean()

# Standardize data
scaler = StandardScaler()
scaled_profiles = scaler.fit_transform(customer_profiles)

# Reduce dimensionality for visualization
pca = PCA(n_components=2)
pca_result = pca.fit_transform(scaled_profiles)

# Apply KMeans clustering
kmeans = KMeans(n_clusters=2, random_state=42)
clusters = kmeans.fit_predict(scaled_profiles)

# Create DataFrame for visualization
cluster_df = pd.DataFrame({
    'CustomerID': customer_profiles.index,
    'PC1': pca_result[:, 0],
    'PC2': pca_result[:, 1],
    'Cluster': clusters
})

# Plot clusters
plt.figure(figsize=(10, 6))
sns.scatterplot(data=cluster_df, x='PC1', y='PC2', hue='Cluster', palette='tab10', s=100)
plt.title("Customer Segmentation Based on Average Consumption")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.legend(title='Cluster')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
from autoarima import automated_forecasts_for_all_types

# %%
# forecast_combined_df = automated_forecasts_for_all_types(pandas_df, selected_columns,forecast_dates)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=10.441, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=4.303, Time=0.05 sec
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=5.700, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=8.590, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=4.057, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,1)[12] intercept   : AIC=4.571, Time=0.05 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=6.237, Time=0.10 sec
#  ARIMA(2,1,0)(0,0,0)[12] intercept   : AIC=6.026, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=6.035, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=5.419, Time=0.02 sec
#  ARIMA(2,1,1)(0,0,0)[12] intercept   : AIC=7.984, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[12]             : AIC=2.559, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12]             : AIC=2.725, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,1)[12]             : AIC=3.029, Time=0.03 sec
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,1,0)(1,0,1)[12]             : AIC=4.642, Time=0.07 sec
#  ARIMA(2,1,0)(0,0,0)[12]             : AIC=4.546, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[12]             : AIC=4.550, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[12]             : AIC=3.920, Time=0.01 sec
#  ARIMA(2,1,1)(0,0,0)[12]             : AIC=6.519, Time=0.04 sec
#
# Best model:  ARIMA(1,1,0)(0,0,0)[12]
# Total fit time: 0.653 seconds
# RMSE of SARIMA  for consumption type PeakConsumption of Podel 736171562 is 99529.49118728339
# RMSE of Baseline for consumption type PeakConsumption of Podel 736171562 is 55885.73275760251
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=5.090, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=2.171, Time=0.06 sec
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=2.741, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=3.336, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=0.783, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,1)[12] intercept   : AIC=2.262, Time=0.07 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=4.066, Time=0.11 sec
#  ARIMA(2,1,0)(0,0,0)[12] intercept   : AIC=2.647, Time=0.02 sec
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=2.702, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=1.403, Time=0.02 sec
#  ARIMA(2,1,1)(0,0,0)[12] intercept   : AIC=inf, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,0)[12]             : AIC=-0.573, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12]             : AIC=0.732, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,1)[12]             : AIC=0.851, Time=0.03 sec
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,1,0)(1,0,1)[12]             : AIC=2.586, Time=0.10 sec
#  ARIMA(2,1,0)(0,0,0)[12]             : AIC=1.338, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[12]             : AIC=1.375, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[12]             : AIC=0.053, Time=0.01 sec
#  ARIMA(2,1,1)(0,0,0)[12]             : AIC=inf, Time=0.08 sec
#
# Best model:  ARIMA(1,1,0)(0,0,0)[12]
# Total fit time: 0.748 seconds
# RMSE of SARIMA  for consumption type StandardConsumption of Podel 736171562 is 257303.89377259713
# RMSE of Baseline for consumption type StandardConsumption of Podel 736171562 is 141017.28365168575
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=-18.897, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=-16.325, Time=0.05 sec
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=-16.221, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=-20.158, Time=0.01 sec
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=-17.941, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=-17.931, Time=0.03 sec
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=-15.960, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=-17.459, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=-17.389, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=-15.504, Time=0.04 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[12]
# Total fit time: 0.297 seconds
# RMSE of SARIMA  for consumption type OffPeakConsumption of Podel 736171562 is 398416.02168106486
# RMSE of Baseline for consumption type OffPeakConsumption of Podel 736171562 is 203964.22397744714
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=nan, Time=0.01 sec
# Error processing Block1Consumption for PodID 736171562: Could not successfully fit a viable ARIMA model to input data.
# See http://alkaline-ml.com/pmdarima/no-successful-model.html for more information on why this can happen.
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\pmdarima\arima\auto.py:444: UserWarning: Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#   warnings.warn('Input time-series is completely constant; '
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\pmdarima\arima\auto.py:444: UserWarning: Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#   warnings.warn('Input time-series is completely constant; '
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=nan, Time=0.01 sec
# Error processing Block2Consumption for PodID 736171562: Could not successfully fit a viable ARIMA model to input data.
# See http://alkaline-ml.com/pmdarima/no-successful-model.html for more information on why this can happen.
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=nan, Time=0.01 sec
# Error processing Block3Consumption for PodID 736171562: Could not successfully fit a viable ARIMA model to input data.
# See http://alkaline-ml.com/pmdarima/no-successful-model.html for more information on why this can happen.
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=nan, Time=0.01 sec
# Error processing Block4Consumption for PodID 736171562: Could not successfully fit a viable ARIMA model to input data.
# See http://alkaline-ml.com/pmdarima/no-successful-model.html for more information on why this can happen.
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=nan, Time=0.01 sec
# Error processing NonTOUConsumption for PodID 736171562: Could not successfully fit a viable ARIMA model to input data.
# See http://alkaline-ml.com/pmdarima/no-successful-model.html for more information on why this can happen.
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=48.073, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=51.748, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=51.645, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=48.362, Time=0.01 sec
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=49.988, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=50.001, Time=0.02 sec
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\pmdarima\arima\auto.py:444: UserWarning: Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#   warnings.warn('Input time-series is completely constant; '
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\pmdarima\arima\auto.py:444: UserWarning: Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#   warnings.warn('Input time-series is completely constant; '
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\pmdarima\arima\auto.py:444: UserWarning: Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#   warnings.warn('Input time-series is completely constant; '
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=inf, Time=0.15 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=49.834, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=49.724, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=inf, Time=0.06 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[12] intercept
# Total fit time: 0.378 seconds
# RMSE of SARIMA  for consumption type PeakConsumption of Podel 3289712697 is 91844.43110936915
# RMSE of Baseline for consumption type PeakConsumption of Podel 3289712697 is 55347.729619701255
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=46.831, Time=0.00 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=50.198, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=49.783, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=47.165, Time=0.01 sec
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=48.801, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=48.807, Time=0.03 sec
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=48.232, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=47.824, Time=0.01 sec
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=inf, Time=0.07 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[12] intercept
# Total fit time: 0.393 seconds
# RMSE of SARIMA  for consumption type StandardConsumption of Podel 3289712697 is 221819.1683858775
# RMSE of Baseline for consumption type StandardConsumption of Podel 3289712697 is 132986.50045743992
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=50.849, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=54.417, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=54.040, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=51.060, Time=0.01 sec
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=52.839, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=52.841, Time=0.02 sec
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=inf, Time=0.17 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=52.438, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=52.052, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=inf, Time=0.08 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[12] intercept
# Total fit time: 0.426 seconds
# RMSE of SARIMA  for consumption type OffPeakConsumption of Podel 3289712697 is 341975.3335147182
# RMSE of Baseline for consumption type OffPeakConsumption of Podel 3289712697 is 199709.00853902134
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=nan, Time=0.01 sec
# Error processing Block1Consumption for PodID 3289712697: Could not successfully fit a viable ARIMA model to input data.
# See http://alkaline-ml.com/pmdarima/no-successful-model.html for more information on why this can happen.
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=nan, Time=0.01 sec
# Error processing Block2Consumption for PodID 3289712697: Could not successfully fit a viable ARIMA model to input data.
# See http://alkaline-ml.com/pmdarima/no-successful-model.html for more information on why this can happen.
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=nan, Time=0.01 sec
# Error processing Block3Consumption for PodID 3289712697: Could not successfully fit a viable ARIMA model to input data.
# See http://alkaline-ml.com/pmdarima/no-successful-model.html for more information on why this can happen.
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=nan, Time=0.01 sec
# Error processing Block4Consumption for PodID 3289712697: Could not successfully fit a viable ARIMA model to input data.
# See http://alkaline-ml.com/pmdarima/no-successful-model.html for more information on why this can happen.
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=nan, Time=0.01 sec
# Error processing NonTOUConsumption for PodID 3289712697: Could not successfully fit a viable ARIMA model to input data.
# See http://alkaline-ml.com/pmdarima/no-successful-model.html for more information on why this can happen.
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=-7.506, Time=0.01 sec
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\pmdarima\arima\auto.py:444: UserWarning: Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#   warnings.warn('Input time-series is completely constant; '
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\pmdarima\arima\auto.py:444: UserWarning: Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#   warnings.warn('Input time-series is completely constant; '
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\pmdarima\arima\auto.py:444: UserWarning: Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#   warnings.warn('Input time-series is completely constant; '
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\pmdarima\arima\auto.py:444: UserWarning: Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#   warnings.warn('Input time-series is completely constant; '
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\pmdarima\arima\auto.py:444: UserWarning: Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#   warnings.warn('Input time-series is completely constant; '
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=-5.391, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=-5.059, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=-9.271, Time=0.01 sec
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=-5.584, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=-5.578, Time=0.02 sec
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=-3.596, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=-7.328, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=-7.025, Time=0.02 sec
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=-5.547, Time=0.04 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[12]
# Total fit time: 0.290 seconds
# RMSE of SARIMA  for consumption type PeakConsumption of Podel 7027193072 is 655608.8977920321
# RMSE of Baseline for consumption type PeakConsumption of Podel 7027193072 is 409614.3198687961
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=-10.618, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=-8.049, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=-7.806, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=-12.426, Time=0.01 sec
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=-8.686, Time=0.08 sec
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=-8.675, Time=0.02 sec
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=-9.983, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=-9.773, Time=0.01 sec
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=-8.170, Time=0.05 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[12]
# Total fit time: 0.459 seconds
# RMSE of SARIMA  for consumption type StandardConsumption of Podel 7027193072 is 1583461.110815823
# RMSE of Baseline for consumption type StandardConsumption of Podel 7027193072 is 962381.4305289878
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=-3.325, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=-0.660, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=-0.659, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=-5.035, Time=0.01 sec
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=-1.488, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=-1.459, Time=0.02 sec
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ...
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=-4.197, Time=0.20 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=-7.244, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=-7.086, Time=0.06 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=-5.273, Time=0.05 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[12]
# Total fit time: 0.772 seconds
# RMSE of SARIMA  for consumption type PeakConsumption of Podel 9849938574 is 475007.5007648124
# RMSE of Baseline for consumption type PeakConsumption of Podel 9849938574 is 227551.18517831448
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=-10.328, Time=0.02 sec
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=-6.962, Time=0.19 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=-6.912, Time=0.09 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=-11.252, Time=0.02 sec
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=-8.582, Time=0.10 sec
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=-8.534, Time=0.05 sec
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=-6.733, Time=0.23 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=-8.713, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=-8.703, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=-6.713, Time=0.10 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[12]
# Total fit time: 0.863 seconds
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# RMSE of SARIMA  for consumption type StandardConsumption of Podel 9849938574 is 1191161.7953184056
# RMSE of Baseline for consumption type StandardConsumption of Podel 9849938574 is 564303.8612299721
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=-1.580, Time=0.02 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=0.956, Time=0.14 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=1.020, Time=0.10 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=-2.551, Time=0.03 sec
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=-0.687, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=-0.551, Time=0.05 sec
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=1.297, Time=0.10 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=-0.106, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=-0.193, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=1.826, Time=0.10 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[12]
# Total fit time: 0.669 seconds
# RMSE of SARIMA  for consumption type OffPeakConsumption of Podel 9849938574 is 1894595.9391250596
# RMSE of Baseline for consumption type OffPeakConsumption of Podel 9849938574 is 840349.1891047766
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\pmdarima\arima\auto.py:444: UserWarning: Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#   warnings.warn('Input time-series is completely constant; '
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=nan, Time=0.02 sec
# Error processing Block1Consumption for PodID 9849938574: Could not successfully fit a viable ARIMA model to input data.
# See http://alkaline-ml.com/pmdarima/no-successful-model.html for more information on why this can happen.
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=nan, Time=0.02 sec
# Error processing Block2Consumption for PodID 9849938574: Could not successfully fit a viable ARIMA model to input data.
# See http://alkaline-ml.com/pmdarima/no-successful-model.html for more information on why this can happen.
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=nan, Time=0.03 sec
# Error processing Block3Consumption for PodID 9849938574: Could not successfully fit a viable ARIMA model to input data.
# See http://alkaline-ml.com/pmdarima/no-successful-model.html for more information on why this can happen.
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=nan, Time=0.03 sec
# Error processing Block4Consumption for PodID 9849938574: Could not successfully fit a viable ARIMA model to input data.
# See http://alkaline-ml.com/pmdarima/no-successful-model.html for more information on why this can happen.
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=nan, Time=0.04 sec
# Error processing NonTOUConsumption for PodID 9849938574: Could not successfully fit a viable ARIMA model to input data.
# See http://alkaline-ml.com/pmdarima/no-successful-model.html for more information on why this can happen.
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\pmdarima\arima\auto.py:444: UserWarning: Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#   warnings.warn('Input time-series is completely constant; '
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\pmdarima\arima\auto.py:444: UserWarning: Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#   warnings.warn('Input time-series is completely constant; '
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\pmdarima\arima\auto.py:444: UserWarning: Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#   warnings.warn('Input time-series is completely constant; '
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\pmdarima\arima\auto.py:444: UserWarning: Input time-series is completely constant; returning a (0, 0, 0) ARMA.
#   warnings.warn('Input time-series is completely constant; '
# C:\Users\molef\anaconda3\envs\data_science\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# C:\Users\molef\Playground\Data Science\Sherpa\Eskom\autoarima.py:140: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   forecast_combined_df[cons_type] = forecast_combined_df[cons_type].fillna(0).round(2)

# %%
# forecast_combined_df
# Out:
#    ReportingMonth  CustomerID       PodID  PeakConsumption  \
# 0      2025-04-01  7397925811   736171562         72801.80
# 1      2025-05-01  7397925811   736171562         75026.67
# 2      2025-06-01  7397925811   736171562         74009.13
# 3      2025-07-01  7397925811   736171562         74468.98
# 4      2025-08-01  7397925811   736171562         74260.03
# 5      2025-09-01  7397925811   736171562         74354.74
# 6      2025-10-01  7397925811   736171562         74311.76
# 7      2025-11-01  7397925811   736171562         74331.26
# 8      2025-12-01  7397925811   736171562         74322.41
# 9      2026-01-01  7397925811   736171562         74326.43
# 10     2026-02-01  7397925811   736171562         74324.61
# 11     2026-03-01  7397925811   736171562         74325.43
# 12     2025-04-01  7397925811  3289712697          2144.50
# 13     2025-05-01  7397925811  3289712697          1898.01
# 14     2025-06-01  7397925811  3289712697          1679.85
# 15     2025-07-01  7397925811  3289712697          1486.77
# 16     2025-08-01  7397925811  3289712697          1315.88
# 17     2025-09-01  7397925811  3289712697          1164.64
# 18     2025-10-01  7397925811  3289712697          1030.77
# 19     2025-11-01  7397925811  3289712697           912.30
# 20     2025-12-01  7397925811  3289712697           807.44
# 21     2026-01-01  7397925811  3289712697           714.63
# 22     2026-02-01  7397925811  3289712697           632.49
# 23     2026-03-01  7397925811  3289712697           559.79
# 24     2025-04-01  7397925811  7027193072        645943.00
# 25     2025-05-01  7397925811  7027193072        645943.00
# 26     2025-06-01  7397925811  7027193072        645943.00
# 27     2025-07-01  7397925811  7027193072        645943.00
# 28     2025-08-01  7397925811  7027193072        645943.00
# 29     2025-09-01  7397925811  7027193072        645943.00
# 30     2025-10-01  7397925811  7027193072        645943.00
# 31     2025-11-01  7397925811  7027193072        645943.00
# 32     2025-12-01  7397925811  7027193072        645943.00
# 33     2026-01-01  7397925811  7027193072        645943.00
# 34     2026-02-01  7397925811  7027193072        645943.00
# 35     2026-03-01  7397925811  7027193072        645943.00
# 36     2025-04-01  7397925811  9849938574        260313.00
# 37     2025-05-01  7397925811  9849938574        260313.00
# 38     2025-06-01  7397925811  9849938574        260313.00
# 39     2025-07-01  7397925811  9849938574        260313.00
# 40     2025-08-01  7397925811  9849938574        260313.00
# 41     2025-09-01  7397925811  9849938574        260313.00
# 42     2025-10-01  7397925811  9849938574        260313.00
# 43     2025-11-01  7397925811  9849938574        260313.00
# 44     2025-12-01  7397925811  9849938574        260313.00
# 45     2026-01-01  7397925811  9849938574        260313.00
# 46     2026-02-01  7397925811  9849938574        260313.00
# 47     2026-03-01  7397925811  9849938574        260313.00
#
#     StandardConsumption  OffPeakConsumption  Block1Consumption  \
# 0             187440.03           270912.00                  0
# 1             192528.54           270912.00                  0
# 2             190495.22           270912.00                  0
# 3             191298.62           270912.00                  0
# 4             190979.76           270912.00                  0
# 5             191106.09           270912.00                  0
# 6             191056.00           270912.00                  0
# 7             191075.85           270912.00                  0
# 8             191067.98           270912.00                  0
# 9             191071.10           270912.00                  0
# 10            191069.87           270912.00                  0
# 11            191070.36           270912.00                  0
# 12              5301.59             7057.04                  0
# 13              4697.00             6228.35                  0
# 14              4161.36             5496.97                  0
# 15              3686.80             4851.47                  0
# 16              3266.36             4281.77                  0
# 17              2893.87             3778.97                  0
# 18              2563.86             3335.21                  0
# 19              2271.48             2943.56                  0
# 20              2012.44             2597.91                  0
# 21              1782.94             2292.84                  0
# 22              1579.62             2023.60                  0
# 23              1399.48             1785.97                  0
# 24           1592076.00          2116820.00                  0
# 25           1592076.00          2116820.00                  0
# 26           1592076.00          2116820.00                  0
# 27           1592076.00          2116820.00                  0
# 28           1592076.00          2116820.00                  0
# 29           1592076.00          2116820.00                  0
# 30           1592076.00          2116820.00                  0
# 31           1592076.00          2116820.00                  0
# 32           1592076.00          2116820.00                  0
# 33           1592076.00          2116820.00                  0
# 34           1592076.00          2116820.00                  0
# 35           1592076.00          2116820.00                  0
# 36            626683.00           832812.00                  0
# 37            626683.00           832812.00                  0
# 38            626683.00           832812.00                  0
# 39            626683.00           832812.00                  0
# 40            626683.00           832812.00                  0
# 41            626683.00           832812.00                  0
# 42            626683.00           832812.00                  0
# 43            626683.00           832812.00                  0
# 44            626683.00           832812.00                  0
# 45            626683.00           832812.00                  0
# 46            626683.00           832812.00                  0
# 47            626683.00           832812.00                  0
#
#     Block2Consumption  Block3Consumption  Block4Consumption  \
# 0                   0                  0                  0
# 1                   0                  0                  0
# 2                   0                  0                  0
# 3                   0                  0                  0
# 4                   0                  0                  0
# 5                   0                  0                  0
# 6                   0                  0                  0
# 7                   0                  0                  0
# 8                   0                  0                  0
# 9                   0                  0                  0
# 10                  0                  0                  0
# 11                  0                  0                  0
# 12                  0                  0                  0
# 13                  0                  0                  0
# 14                  0                  0                  0
# 15                  0                  0                  0
# 16                  0                  0                  0
# 17                  0                  0                  0
# 18                  0                  0                  0
# 19                  0                  0                  0
# 20                  0                  0                  0
# 21                  0                  0                  0
# 22                  0                  0                  0
# 23                  0                  0                  0
# 24                  0                  0                  0
# 25                  0                  0                  0
# 26                  0                  0                  0
# 27                  0                  0                  0
# 28                  0                  0                  0
# 29                  0                  0                  0
# 30                  0                  0                  0
# 31                  0                  0                  0
# 32                  0                  0                  0
# 33                  0                  0                  0
# 34                  0                  0                  0
# 35                  0                  0                  0
# 36                  0                  0                  0
# 37                  0                  0                  0
# 38                  0                  0                  0
# 39                  0                  0                  0
# 40                  0                  0                  0
# 41                  0                  0                  0
# 42                  0                  0                  0
# 43                  0                  0                  0
# 44                  0                  0                  0
# 45                  0                  0                  0
# 46                  0                  0                  0
# 47                  0                  0                  0
#
#     NonTOUConsumption  UserForecastMethodID
# 0                   0                    64
# 1                   0                    64
# 2                   0                    64
# 3                   0                    64
# 4                   0                    64
# 5                   0                    64
# 6                   0                    64
# 7                   0                    64
# 8                   0                    64
# 9                   0                    64
# 10                  0                    64
# 11                  0                    64
# 12                  0                    64
# 13                  0                    64
# 14                  0                    64
# 15                  0                    64
# 16                  0                    64
# 17                  0                    64
# 18                  0                    64
# 19                  0                    64
# 20                  0                    64
# 21                  0                    64
# 22                  0                    64
# 23                  0                    64
# 24                  0                    64
# 25                  0                    64
# 26                  0                    64
# 27                  0                    64
# 28                  0                    64
# 29                  0                    64
# 30                  0                    64
# 31                  0                    64
# 32                  0                    64
# 33                  0                    64
# 34                  0                    64
# 35                  0                    64
# 36                  0                    64
# 37                  0                    64
# 38                  0                    64
# 39                  0                    64
# 40                  0                    64
# 41                  0                    64
# 42                  0                    64
# 43                  0                    64
# 44                  0                    64
# 45                  0                    64
# 46                  0                    64
# 47                  0                    64
